# %% [markdown]
# # **Dataset: IMDB (Internet Movie Database)**

# %% [markdown]
# # **1: Implementing a Basic RNN Model**

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

tf.random.set_seed(42)  # Random seed for reproducibility

# %%
max_features = 10000
maxlen = 500
batch_size = 32

# %%
(input_train, y_train), (input_test, y_test) = imdb.load_data(num_words=max_features)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Data Preprocessing by Padding Sequence
input_train = sequence.pad_sequences(input_train, maxlen=maxlen)
input_test = sequence.pad_sequences(input_test, maxlen=maxlen)

# %%
# Building RNN model
model = Sequential()
model.add(Embedding(max_features, 32))
model.add(SimpleRNN(32, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(input_train, y_train, epochs=10, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 129ms/step - accuracy: 0.6028 - loss: 0.6412 - val_accuracy: 0.8306 - val_loss: 0.3900
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 124ms/step - accuracy: 0.8302 - loss: 0.3938 - val_accuracy: 0.8602 - val_loss: 0.3484
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 124ms/step - accuracy: 0.8631 - loss: 0.3279 - val_accuracy: 0.8608 - val_loss: 0.3416
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 127ms/step - accuracy: 0.8992 - loss: 0.2591 - val_accuracy: 0.8600 - val_loss: 0.3604
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.9237 - loss: 0.2040 - val_accuracy: 0.8366 - val_loss: 0.3979
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.9287 - loss: 0.1829 - val_accuracy: 0.8282 - val_loss: 0.4455
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 126ms/step - accuracy: 0.9474 - loss: 0.1382 - val_accuracy: 0.8492 - val_loss: 0.4876
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.9618 - loss: 0.1051 - val_accuracy: 0.8366 - val_loss: 0.5204
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 129ms/step - accuracy: 0.9748 - loss: 0.0753 - val_accuracy: 0.8416 - val_loss: 0.5690
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 136ms/step - accuracy: 0.9825 - loss: 0.0559 - val_accuracy: 0.8364 - val_loss: 0.6195

# %%
# Model Evaluation
test_loss, test_acc = model.evaluate(input_test, y_test)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.8318 - loss: 0.6346
# Test Accuracy: 0.8332

# %% [markdown]
# # **2: Stacking RNN Layers and Bi-directional RNNs**

# %% [markdown]
# **Stacked RNN Model**

# %%
# Building Stacked RNN Model
stacked_model = Sequential()
stacked_model.add(Embedding(max_features, 32))
stacked_model.add(SimpleRNN(32, return_sequences=True))  # 1st layer
stacked_model.add(SimpleRNN(32, return_sequences=False))  # 2nd layer
stacked_model.add(Dense(1, activation='sigmoid'))

# %%
# Compiling model
stacked_model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history_stacked = stacked_model.fit(input_train, y_train, epochs=10, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 153s 241ms/step - accuracy: 0.5523 - loss: 0.6769 - val_accuracy: 0.8144 - val_loss: 0.4236
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 197s 233ms/step - accuracy: 0.8188 - loss: 0.4079 - val_accuracy: 0.7914 - val_loss: 0.5083
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 205s 237ms/step - accuracy: 0.8796 - loss: 0.2949 - val_accuracy: 0.8044 - val_loss: 0.4390
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 204s 242ms/step - accuracy: 0.9131 - loss: 0.2222 - val_accuracy: 0.8526 - val_loss: 0.4078
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 199s 237ms/step - accuracy: 0.9422 - loss: 0.1591 - val_accuracy: 0.8332 - val_loss: 0.5338
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 205s 242ms/step - accuracy: 0.9587 - loss: 0.1148 - val_accuracy: 0.8192 - val_loss: 0.5966
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 151s 242ms/step - accuracy: 0.9728 - loss: 0.0756 - val_accuracy: 0.7960 - val_loss: 0.7388
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 150s 240ms/step - accuracy: 0.9871 - loss: 0.0444 - val_accuracy: 0.7996 - val_loss: 0.8103
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 201s 239ms/step - accuracy: 0.9902 - loss: 0.0310 - val_accuracy: 0.7716 - val_loss: 1.1212
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 200s 235ms/step - accuracy: 0.9923 - loss: 0.0220 - val_accuracy: 0.7010 - val_loss: 1.4139

# %%
test_loss_stacked, test_acc_stacked = stacked_model.evaluate(input_test, y_test)
print(f'Stacked RNN Test Accuracy: {test_acc_stacked:.4f}')
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 46s 58ms/step - accuracy: 0.6998 - loss: 1.3923
# Stacked RNN Test Accuracy: 0.6998

# %% [markdown]
# **Bi-directional RNN Model**

# %%
from tensorflow.keras.layers import Bidirectional

bidirectional_model = Sequential()
bidirectional_model.add(Embedding(max_features, 32))
bidirectional_model.add(Bidirectional(SimpleRNN(32)))
bidirectional_model.add(Dense(1, activation='sigmoid'))

# %%
bidirectional_model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history_bidirectional = bidirectional_model.fit(input_train, y_train, epochs=10, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 135s 211ms/step - accuracy: 0.5570 - loss: 0.6732 - val_accuracy: 0.7710 - val_loss: 0.4889
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 149s 223ms/step - accuracy: 0.8121 - loss: 0.4269 - val_accuracy: 0.8314 - val_loss: 0.3847
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 144s 225ms/step - accuracy: 0.8602 - loss: 0.3438 - val_accuracy: 0.8542 - val_loss: 0.3598
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 138s 219ms/step - accuracy: 0.8753 - loss: 0.3086 - val_accuracy: 0.8520 - val_loss: 0.3573
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 145s 224ms/step - accuracy: 0.8932 - loss: 0.2784 - val_accuracy: 0.8444 - val_loss: 0.3771
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 138s 217ms/step - accuracy: 0.9086 - loss: 0.2307 - val_accuracy: 0.8310 - val_loss: 0.4187
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 135s 216ms/step - accuracy: 0.9284 - loss: 0.1905 - val_accuracy: 0.8418 - val_loss: 0.4891
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 145s 222ms/step - accuracy: 0.9439 - loss: 0.1561 - val_accuracy: 0.8510 - val_loss: 0.4665
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 138s 216ms/step - accuracy: 0.9514 - loss: 0.1374 - val_accuracy: 0.8500 - val_loss: 0.4787
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 136s 217ms/step - accuracy: 0.9600 - loss: 0.1124 - val_accuracy: 0.8430 - val_loss: 0.5174

# %%
test_loss_bidirectional, test_acc_bidirectional = bidirectional_model.evaluate(input_test, y_test)
print(f'Bi-directional RNN Test Accuracy: {test_acc_bidirectional:.4f}')
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8370 - loss: 0.5315
# Bi-directional RNN Test Accuracy: 0.8374

# %% [markdown]
# # **3: Exploring Hybrid Architectures**
# **Combining RNN and CNN Models**

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D

# Building Hybrid Model (RNN + CNN)
hybrid_model = Sequential()
hybrid_model.add(Embedding(max_features, 32))
hybrid_model.add(Conv1D(32, 7, activation='relu'))
hybrid_model.add(MaxPooling1D(5))
hybrid_model.add(Conv1D(32, 7, activation='relu'))
hybrid_model.add(GlobalMaxPooling1D())
hybrid_model.add(Dense(32, activation='relu'))
hybrid_model.add(Dense(1, activation='sigmoid'))

# %%
hybrid_model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history_hybrid = hybrid_model.fit(input_train, y_train, epochs=10, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 31s 45ms/step - accuracy: 0.6052 - loss: 0.6222 - val_accuracy: 0.8548 - val_loss: 0.3413
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.8664 - loss: 0.3197 - val_accuracy: 0.8790 - val_loss: 0.2978
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9083 - loss: 0.2382 - val_accuracy: 0.8836 - val_loss: 0.2939
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.9332 - loss: 0.1844 - val_accuracy: 0.8816 - val_loss: 0.3067
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 45ms/step - accuracy: 0.9536 - loss: 0.1372 - val_accuracy: 0.8802 - val_loss: 0.3346
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 46ms/step - accuracy: 0.9714 - loss: 0.0925 - val_accuracy: 0.8796 - val_loss: 0.3768
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 46ms/step - accuracy: 0.9851 - loss: 0.0528 - val_accuracy: 0.8798 - val_loss: 0.4411
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 44ms/step - accuracy: 0.9931 - loss: 0.0276 - val_accuracy: 0.8762 - val_loss: 0.5699
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9946 - loss: 0.0174 - val_accuracy: 0.8730 - val_loss: 0.6732
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9975 - loss: 0.0084 - val_accuracy: 0.8808 - val_loss: 0.7610

# %%
test_loss_hybrid, test_acc_hybrid = hybrid_model.evaluate(input_test, y_test)
print(f'Hybrid RNN+CNN Test Accuracy: {test_acc_hybrid:.4f}')
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.8660 - loss: 0.7998
# Hybrid RNN+CNN Test Accuracy: 0.8655
